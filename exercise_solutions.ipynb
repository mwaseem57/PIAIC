# %%
#1. Simple Message
var = 'This a a sample message'
print(var)

#2. Simple Messages

var = 'Updated sample message'
print(var)

#3.Personal Message

name = 'Eric'
print("Hello " +name+ ", would you like to learn some Python today?")

#4. Name Cases

upperCase = name.upper()
print("This is an Upper Case Text " + upperCase)

lowerCase = name.lower()
print("This is a lower case Text " + lowerCase)

titleCase = name.title()
print("This is a title case text " + titleCase)

#5. Famous Quote

quote = '"A friend in need is a friend indeed"'
print(name + "once said, "+quote)

#6. Famous Quote 2
famouse_person = 'Bob Marley'
message = 'Emancipate yourselves from mental slavery, none but ourselves can free our minds'
print(famouse_person + " said " +'"'+ message, end='"')

#7. Stripping Names
print('\n\t'+ famouse_person + '\t'+'"')

#8. Variable Sum
x=5 
y=10
z=15
print(x+y+z)

#9. Variable Swap
print("value of the first variable is "+str(x))
print("value of the second variable is "+str(y))

print("after swapping variables the values are: ")

temp = y
y = x
x = temp

print(x)
print(y)

#10. Favorite Color

favColor = 'Black'
print("My favourite color: "+ favColor)
updatedFacColor = favColor
print("Favourite color with a another variable is: "+ updatedFacColor)

#11. Changing Pet Name

pet_name = 'Buddy'
print(pet_name)
pet_name = 'Max'
print(pet_name)



#13. Reassigning Score

score = 100
print(score)
score = 200
print(score)


#14. City Name

city = 'Istanbul'
print(city)

#15. Title Case Text

text = 'python programming'
print(text.title())

#16. Lowercase Conversion

mixed = 'This is A STRING'
print(mixed.lower())

#17. Uppercase Conversion

mixed1 = 'This is anOTher STRING'
print(mixed1.upper())


#18. Current Temperature

temperature = 25
print("The current temperature is " + str(temperature) + " degrees.")


#19. Printing a Poem

poem = """Early to bed, 
early to rise,
Makes a man
healthy, wealthy, and wise."""

print(poem)



#12. Observing Name Error

varX = 'Sunshine'
#print(sunShine)
# Out:
# This a a sample message
# Updated sample message
# Hello Eric, would you like to learn some Python today?
# This is an Upper Case Text ERIC
# This is a lower case Text eric
# This is a title case text Eric
# Ericonce said, "A friend in need is a friend indeed"
# Bob Marley said "Emancipate yourselves from mental slavery, none but ourselves can free our minds"
# 	Bob Marley	"
# 30
# value of the first variable is 5
# value of the second variable is 10
# after swapping variables the values are:
# 10
# 5
# My favourite color: Black
# Favourite color with a another variable is: Black
# Buddy
# Max
# 100
# 200
# Istanbul
# Python Programming
# this is a string
# THIS IS ANOTHER STRING
# The current temperature is 25 degrees.
# Early to bed,
# early to rise,
# Makes a man
# healthy, wealthy, and wise.
